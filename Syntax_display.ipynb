# %% [markdown]
# <a href="https://colab.research.google.com/github/DAclarissememba-png/DAclarissememba/blob/main/Syntax_display.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = {"apple", "banana", "cherry"}
print(fruits)    # order may be different each time
# Out:
# {'banana', 'apple', 'cherry'}

# %%
fruits = {"apple", "banana", "apple"}
print(fruits)
# Out:
# {'banana', 'apple'}

# %%
fruits = {"apple", "banana", "cherry"}
fruits.discard("banana")  # Removes it
fruits.discard("orange")
print(fruits)
# Out:
# {'apple', 'cherry'}

# %%
a = {1, 2, 3}
b = {3, 4}
print((a.union(b)))
# Out:
# {1, 2, 3, 4}

# %%
animals={"dog", "cat","bear"}
len(animals)
# Out:
# 3

# %%
student = {
   "name": "Ali",
   "age": 20,
  "course": "Python"
}
print(student)
# Out:
# {'name': 'Ali', 'age': 20, 'course': 'Python'}

# %%
print(student["name"])          # Ali
print(student.get("age"))       # 20
# Out:
# Ali
# 20

# %%
import pandas as pd
numbers = pd.Series([10, 20, 30, 40])
print (numbers)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
data = {
   "Name": ["Tom", "Anna", "Ravi"],
  "Age":  [25,     30,    22]
}
print(data)
# Out:
# {'Name': ['Tom', 'Anna', 'Ravi'], 'Age': [25, 30, 22]}

# %%
df = pd.DataFrame(data)
print (df)
# Out:
#    Name  Age
# 0   Tom   25
# 1  Anna   30
# 2  Ravi   22

# %%
isinstance(df, pd.DataFrame)
# Out:
# True

# %%
# !pip --version
# Out:
# pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)

# %%
import pandas as pd
data = {
   "calories": [420, 380, 390],
   "duration": [50, 40, 45]
}
#load data into a DataFrame object:
df = pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
# Connect this notebook to your Google Drive
from google. colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d75cc8b8-2280-4e8d-8057-583d1ea8d4a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d75cc8b8-2280-4e8d-8057-583d1ea8d4a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('student.csv')
df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
df.head()
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female
