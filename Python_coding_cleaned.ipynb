# %% [markdown]
# <a href="https://colab.research.google.com/github/DAclarissememba-png/DAclarissememba/blob/main/Python_coding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>

# %%
# ==== SETUP: import libraries ====
# Core libraries for data analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Global display options (optional)
pd.set_option("display.max_rows", 10)
sns.set(style="whitegrid")

print("Setup complete")
# Out:
# Setup complete

# %%
# Load the GDP data
df = pd.read_csv('GDP (nominal) per Capita.csv')  # Update path as needed
print(f"Dataset loaded")
print(f"Shape: {df.shape}")
df.head()

# %%
# Clean up whitespace in country/territory names
df['Country/Territory'] = df['Country/Territory'].str.strip()

# Verify cleaned data
df.head()
